# %% [markdown]
# # FORMULACIÓN DEL MODELO DE OPTIMIZACIÓN

# %% [markdown]
# La formulación del modelo se basa en la representación matemática de las relaciones entre actores de la red planteada. Para esto se formula un algoritmos de programación lineal de enteros mixtos (MILP) que contemple el problema de asignación de cantidad optima de cada tipo de queso y operación de agentes dentro de la red, para llegar a la modelación definitiva se lleva a cabo las distintas pruebas de funcionalidad con el fin de validad cada una de las restricciones, supuestos y variables de salida, con el fin de verificar la validez de los resultados.

# %% [markdown]
# ## Modelo de optimización

# %% [markdown]
# ### 1. Importa la librería

# %%
# Instalando biblioteca pyomo y GLPK
# Instalando Pyomo
# pip3 install pyomo
# pip3 install pandas

# %%
import csv
import pandas as pd
from pyomo.environ import*
import pyomo.environ as pyo

# %% [markdown]
# ### 2. Crea un modelo de Pyomo

# %%
# Crear un modelo abstracto con Pyomo
modelo = pyo.AbstractModel()

# %% [markdown]
# ### 3. Cargamos los parametros

# %%
# Cargar datos desde archivos CSV
# Asumiendo que tienes archivos CSV llamados 'costo_produccion.csv', 'costo_fijo_acopio.csv', etc.
# Ajusta los nombres de archivos según tus necesidades

productores_df = pd.read_csv('Productores.csv', index_col='Productores')
centros_de_acopios_df = pd.read_csv('CAcopios.csv', index_col='CAcopios')
clientes_df = pd.read_csv('Clientes.csv', index_col='Clientes')
productos_df = pd.read_csv('Productos.csv', index_col='Productos')
periodo_de_tiempo_df = pd.read_csv('Tiempo.csv', index_col='Tiempo')

# Lee los DataFrames desde archivos CSV
costo_produccion_df = pd.read_csv('CostoProduccion.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
costo_fijo_acopio_df = pd.read_csv('CostoFijoAcopio.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
costo_var_acopio_df = pd.read_csv('CostoVarAcopio.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
costo_inv_acopio_df = pd.read_csv('CostoInvAcopio.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
costo_trans_prod_acopio_df = pd.read_csv('CostoTransProdAcopio.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
costo_trans_acopio_clie_df = pd.read_csv('CostoTransAcopioClie.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
demanda_clie_df = pd.read_csv('DemandaClie.csv', delimiter=';', decimal=',', encoding='utf-8-sig') 
cap_productor_df = pd.read_csv('CapProductor.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
cap_almacenamientoCA_df = pd.read_csv('CapAlmacenamientoCA.csv', delimiter=';', decimal=',', encoding='utf-8-sig')  
precio_df = pd.read_csv('Precio.csv', delimiter=';', decimal=',', encoding='utf-8-sig')

# Convertir los DataFrames a diccionarios
costo_produccion_dict = costo_produccion_df.set_index(['Productos', 'Productores', 'Tiempo'])['CostoProduccion'].to_dict()
costo_fijo_acopio_dict = costo_fijo_acopio_df.set_index(['CAcopios', 'Tiempo'])['CostoFijoAcopio'].to_dict()
costo_var_acopio_dict = costo_var_acopio_df.set_index(['Productos', 'CAcopios', 'Tiempo'])['CostoVarAcopio'].to_dict()
costo_inv_acopio_dict = costo_inv_acopio_df.set_index(['Productos', 'CAcopios', 'Tiempo'])['CostoInvAcopio'].to_dict()
costo_trans_prod_acopio_dict = costo_trans_prod_acopio_df.set_index(['Productos', 'Productores', 'CAcopios', 'Tiempo'])['CostoTransProdAcopio'].to_dict()
costo_trans_acopio_clie_dict = costo_trans_acopio_clie_df.set_index(['Productos', 'CAcopios', 'Clientes', 'Tiempo'])['CostoTransAcopioClie'].to_dict()
demanda_clie_dict = demanda_clie_df.set_index(['Productos', 'Clientes', 'Tiempo'])['DemandaClie'].to_dict()
cap_productor_dict = cap_productor_df.set_index(['Productos', 'Productores', 'Tiempo'])['CapProductor'].to_dict()
cap_almacenamientoCA_dict = cap_almacenamientoCA_df.set_index(['Productos', 'CAcopios', 'Tiempo'])['CapAlmacenamientoCA'].to_dict()
precio_dict = precio_df.set_index(['Productos', 'Tiempo'])['Precio'].to_dict()

# %%
# Antes de la creación de los conjuntos, agrega estas líneas
print("Claves de los conjuntos:")
print("Productores:", productores_df.index)
print("Centros de acopios:", centros_de_acopios_df.index)
print("Clientes:", clientes_df.index)
print("Productos:", productos_df.index)
print("Periodo de tiempo:", periodo_de_tiempo_df.index)

# Luego de la creación de los diccionarios, agrega estas líneas
print("\nClaves de los diccionarios:")
print("CostoProduccion:", costo_produccion_dict.keys())
print("CostoFijoAcopio:", costo_fijo_acopio_dict.keys())
print("CostoVarAcopio:", costo_var_acopio_dict.keys())
print("CostoInvAcopio:", costo_inv_acopio_dict.keys())
print("CostoTransProdAcopio:", costo_trans_prod_acopio_dict.keys())
print("CostoTransAcopioClie:", costo_trans_acopio_clie_dict.keys())
print("DemandaClie:", demanda_clie_dict.keys())
print("CapProductor:", cap_productor_dict.keys())
print("CapAlmacenamientoCA:", cap_almacenamientoCA_dict.keys())
print("Precio:", precio_dict.keys())

# %% [markdown]
# ### 4. Conjuntos
#
# | Término | Descripción                    |
# |---------|--------------------------------|
# | I       | Conjunto de productores        |
# | J       | Conjunto de centros de acopio  |
# | K       | Conjunto de clientes           |
# | P       | Conjunto de productos          |
# | T       | Conjunto de periodos de tiempo |

# %%
modelo.productores = pyo.Set(initialize=productores_df.index)  # Conjunto I de productores
modelo.centros_de_acopios = pyo.Set(initialize=centros_de_acopios_df.index)  # Conjunto J de centros de acopio
modelo.clientes = pyo.Set(initialize=clientes_df.index)  # Conjunto K de clientes
modelo.productos = pyo.Set(initialize=productos_df.index)  # Conjunto P de productos
modelo.periodo_de_tiempo = pyo.Set(initialize=periodo_de_tiempo_df.index)  # Conjunto T de periodos de tiempo

# %% [markdown]
# ### 5. Parámetros

# %% [markdown]
# | Término                       | Descripción                                                                       | Unidades    |
# |-------------------------------|-----------------------------------------------------------------------------------|-------------|
# | Costos de producción          |                                                                               |             |
# | $CostoProducción_{pit}$        | Costo de producción del producto p en el productor i en el periodo de tiempo t    | [$/kg]      |
# | Costos de operación           |                                                                               |             |
# | $CostoFijoAcopi_{jt}$         | Costo fijo del centro de acopio j en el periodo de tiempo t                        | [$]         |
# | $CostoVarAcopio_{pjt}$         | Costo variable del producto p en el centro de acopio j en el periodo de tiempo t  | [$/kg]      |
# | Costos de inventario          |                                                                               |             |
# | $CostoInvAcopio_{pjt}$         | Costo de inventario del producto p en el centro de acopio j en el periodo de tiempo t | [$/kg]   |
# | Costos de transporte          |                                                                               |             |
# | $CostoTransProdAcopi_{pijt}$  | Costo de transporte del producto p desde el productor i hasta el centro de acopio j en el periodo de tiempo t | [$/kg] |
# | $CostoTransAcopioClie_{pjkt}$  | Costo de transporte del producto p desde el centro de acopio j hasta el cliente k en el periodo de tiempo t | [$/kg] |
# | Demanda                       |                                                                               |             |
# | $DemandaClie_{pkt}$            | Demanda del producto p en el cliente k en el periodo de tiempo t                  | [kg]        |
# | Capacidades                   |                                                                               |             |
# | $CapProductor_{pit}$           | Capacidad de suministro del producto p en el productor i en el periodo de tiempo t | [kg]        |
# | $CapAlmacenamientoCA_{pjt}$    | Capacidad de almacenamiento del producto p en el centro de acopio j en el periodo de tiempo t | [kg]   |
# | $Precio_{pt}$    | Precio del producto p en el periodo de tiempo t | [$/kg]   |

# %%
modelo.CostoProduccion = pyo.Param(modelo.productos, modelo.productores, modelo.periodo_de_tiempo, initialize = costo_produccion_dict)
modelo.CostoFijoAcopio = pyo.Param(modelo.centros_de_acopios, modelo.periodo_de_tiempo, initialize = costo_fijo_acopio_dict)
modelo.CostoVarAcopio = pyo.Param(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, initialize = costo_var_acopio_dict)
modelo.CostoInvAcopio = pyo.Param(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, initialize = costo_inv_acopio_dict)
modelo.CostoTransProdAcopio = pyo.Param(modelo.productos, modelo.productores, modelo.centros_de_acopios, modelo.periodo_de_tiempo, initialize = costo_trans_prod_acopio_dict)
modelo.CostoTransAcopioClie = pyo.Param(modelo.productos, modelo.centros_de_acopios, modelo.clientes, modelo.periodo_de_tiempo, initialize = costo_trans_acopio_clie_dict)
modelo.DemandaClie = pyo.Param(modelo.productos, modelo.clientes, modelo.periodo_de_tiempo, initialize = demanda_clie_dict)
modelo.CapProductor = pyo.Param(modelo.productos, modelo.productores, modelo.periodo_de_tiempo, initialize = cap_productor_dict)
modelo.CapAlmacenamientoCA = pyo.Param(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, initialize = cap_almacenamientoCA_dict)
modelo.Precio = pyo.Param(modelo.productos, modelo.periodo_de_tiempo, initialize = precio_dict)

# %% [markdown]
# ### 6. Variables de decisión

# %% [markdown]
# | Término                 | Descripción                                                                       | Unidades  |
# |-------------------------|-----------------------------------------------------------------------------------|-----------|
# | Variables de operación  |                                                                               |           |
# | $CA_{jt}$               | 1 si se opera un centro de acopio j en el periodo de tiempo t; 0 en caso contrario | [binaria] |
# | $AS_{ijt}$              | 1 si se asigna un envío de i a j en el periodo de tiempo t; 0 en caso contrario   | [binaria] |
# | Variables de flujo      |                                                                               |           |
# | $PA_{pijt}$             | Cantidad del producto p por enviar desde el productor i hasta el centro de acopio j en el periodo de tiempo t | [kg]      |
# | $AC_{pjkt}$             | Cantidad del producto p por enviar desde el centro de acopio j al cliente k en el periodo de tiempo t       | [kg]      |
# | Variables de inventario |                                                                               |           |
# | $InvCA_{pjt}$           | Inventario del producto p en el centro de acopio j en el periodo de tiempo t     | [kg]      |

# %%
modelo.CA = pyo.Var(modelo.centros_de_acopios, modelo.periodo_de_tiempo, within=pyo.Binary)
modelo.AS = pyo.Var(modelo.productores, modelo.centros_de_acopios, modelo.periodo_de_tiempo, within=pyo.Binary)
modelo.PA = pyo.Var(modelo.productos, modelo.productores, modelo.centros_de_acopios, modelo.periodo_de_tiempo, within=pyo.NonNegativeReals)
modelo.AC = pyo.Var(modelo.productos, modelo.centros_de_acopios, modelo.clientes, modelo.periodo_de_tiempo, within=pyo.NonNegativeReals)
modelo.InvCA = pyo.Var(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, within=pyo.NonNegativeReals)

# %% [markdown]
# ### 7. Restricciones de capacidad y demanda

# %% [markdown]
# (2) De Capacidad de productores:
# \begin{align*}
# & PA_{pijt} = \text{CapProductor}_{pit} \cdot \text{AS}_{ijt} \quad \forall p \in P, \forall i \in I, \forall j \in J, \forall t \in T
# \end{align*}
#
# (3) De Flujo:
#
# En los centros de acopio
#
# \begin{align*}
# & \sum_{i \in I} PA_{pijt} = \text{InvCA}_{pjt} + \sum_{k \in K} AC_{pjkt} \quad \forall p \in P, \forall j \in J, t=1 \
# \\
# \\
# & \sum_{i \in I} PA_{pijt} + \text{InvCA}_{pjt-1} = \text{InvCA}_{pjt} + \sum_{k \in K} AC_{pjkt} \quad \forall p \in P, \forall j \in J, t \geq 2
# \end{align*}
#
# (4) De relación de variables binarias y de Operación:
# \begin{align*}
# & \sum_{i \in I} PA_{pijt} \leq CA_{jt} \cdot \text{CapAlmacenamientoCA}_{pjt} \quad \forall i \in I, \forall i \in I, \forall p \in P, \forall t \in T
# \end{align*}
#
# (5) Asignación:
# \begin{align*}
# & \sum_{j \in J} AS_{ijt} = 1 \quad \forall j \in J, \forall i \in I, \forall p \in P
# \end{align*}
#
# (6) Demanda satisfecha:
# \begin{align*}
# & \sum_{j \in J} \sum_{k \in K} AC_{pjkt} \leq \sum_{k \in K} \text{DemandaClie}_{pkt} \quad \forall t \in T, \forall p \in P
# \end{align*}

# %%
def cap_productor_rule(modelo, p, i, j, t):
    return modelo.PA[p, i, j, t] <= modelo.CapProductor[p, i, t] * modelo.AS[i, j, t]


modelo.cap_productor = pyo.Constraint(modelo.productos, modelo.productores, modelo.centros_de_acopios, modelo.periodo_de_tiempo, rule=cap_productor_rule)

def flujo_acopio_rule(modelo, p, j, t):
    if t == 1:
        return sum(modelo.PA[p, i, j, t] for i in modelo.productores) == modelo.InvCA[p, j, t] + sum(modelo.AC[p, j, k, t] for k in modelo.clientes)
    else:
        return (
            sum(modelo.PA[p, i, j, t] for i in modelo.productores)
            + modelo.InvCA[p, j, t - 1]
            == modelo.InvCA[p, j, t] + sum(modelo.AC[p, j, k, t] for k in modelo.clientes)
        )

modelo.flujo_acopio = pyo.Constraint(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, rule=flujo_acopio_rule)

def binarias_operacion_rule(modelo, p, j, t):
    return sum(modelo.PA[p, i, j, t] for i in modelo.productores) <= modelo.CA[j, t] * modelo.CapAlmacenamientoCA[p, j, t]

modelo.binarias_operacion = pyo.Constraint(modelo.productos, modelo.centros_de_acopios, modelo.periodo_de_tiempo, rule=binarias_operacion_rule)

def binaria_asignacion_rule(modelo, i, t):
    return sum(modelo.AS[i, j, t] for j in modelo.centros_de_acopios) == 1

modelo.binaria_asignacion = pyo.Constraint(modelo.productores, modelo.periodo_de_tiempo, rule=binaria_asignacion_rule)

def demanda_satisfecha_rule(modelo, p, t):
    return (
        sum(modelo.AC[p, j, k, t] for j in modelo.centros_de_acopios for k in modelo.clientes) 
        <= sum(modelo.DemandaClie[p, k, t] for k in modelo.clientes)
    )

modelo.demanda_satisfecha = pyo.Constraint(modelo.productos, modelo.periodo_de_tiempo, rule=demanda_satisfecha_rule)

# %% [markdown]
# ### 8. Función objetivo

# %% [markdown]
# FUNCION OBJETIVO
# \
# \
# $Max F$= $Ingresos_{t}$ - $CProducción_{t}$-$COperación_{t}$-$CInventario_{t}$-$CTransporte_{t}$] (1)

# %% [markdown]
# \begin{align*}
#
# & Ingresos_t = \sum_{p \in P} \sum_{i \in I} \sum_{j \in J} \text{Precio}_{pt} \cdot \text{PA}_{pijt} \quad \forall t \in T \\
# \\
# & CProduccion_t = \sum_{p \in P} \sum_{i \in I} \sum_{j \in J} \text{CostoProduccion}_{pit} \cdot \text{PA}_{pijt} \quad \forall t \in T \\
# \\
# & COperacion_t = \sum_{j \in J} \text{CostoFijoAcopio}_{jt} \cdot \text{CA}_{jt} + \sum_{p \in P} \sum_{i \in I} \sum_{j \in J} \text{CostoVarAcopio}_{pjt} \cdot \text{PA}_{pijt} \quad \forall t \in T \\
# \\
# & \text{CInventario}_t = \sum_{p \in P} \sum_{j \in J} \text{CostoInvAcopio}_{pjt} \cdot \text{InvCA}_{pjt} \quad \forall t \in T \\
# \\
# & \text{CTransporte}_t = \sum_{p \in P} \sum_{i \in I} \sum_{J \in J} \text{CostoTransProdAcopio}_{pijt} \cdot \text{PA}_{pijt} + \sum_{p \in P} \sum_{j \in J} \sum_{k \in K} \text{CostoTransAcopioClie}_{pjkt} \cdot \text{AC}_{pjkt} \quad \forall t \in T \\
# \\
# \end{align*}

# %%
# Función Objetivo
def objective_rule(modelo):
    return sum(
        modelo.Precio[p, t] * modelo.PA[p, i, j, t]
        for p in modelo.productos
        for i in modelo.productores
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) - (sum(
        modelo.CostoProduccion[p, i, t] * modelo.PA[p, i, j, t]
        for p in modelo.productos
        for i in modelo.productores
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) + sum(
        modelo.CostoFijoAcopio[j, t] * modelo.CA[j, t]
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) + sum(
        modelo.CostoVarAcopio[p, j, t] * modelo.PA[p, i, j, t]
        for p in modelo.productos
        for i in modelo.productores
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) + sum(
        modelo.CostoInvAcopio[p, j, t] * modelo.InvCA[p, j, t]
        for p in modelo.productos
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) + sum(
        modelo.CostoTransProdAcopio[p, i, j, t] * modelo.PA[p, i, j, t]
        for p in modelo.productos
        for i in modelo.productores
        for j in modelo.centros_de_acopios
        for t in modelo.periodo_de_tiempo
    ) + sum(
        modelo.CostoTransAcopioClie[p, j, k, t] * modelo.AC[p, j, k, t]
        for p in modelo.productos
        for j in modelo.centros_de_acopios
        for k in modelo.clientes
        for t in modelo.periodo_de_tiempo
    ))

modelo.objetivo = pyo.Objective(rule=objective_rule, sense=pyo.maximize)

# %% [markdown]
# ### 9. Resuelve el modelo

# %%
# Resuelve el modelo
# Crear una instancia del modelo
instancia_modelo = modelo.create_instance()

# Resolver el problema
solucion = pyo.SolverFactory('glpk').solve(instancia_modelo, tee=True)

# Imprimir resultados
print("Estado del solver:", solucion.solver.status)
print("Condición de terminación:", solucion.solver.termination_condition)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\UNIMAG\AppData\Local\Temp\tmpembma3ay.glpk.raw --wglp C:\Users\UNIMAG\AppData\Local\Temp\tmpopgcecj9.glpk.glp
#  --cpxlp C:\Users\UNIMAG\AppData\Local\Temp\tmpaffhab1s.pyomo.lp
# Reading problem data from 'C:\Users\UNIMAG\AppData\Local\Temp\tmpaffhab1s.pyomo.lp'...
# C:\Users\UNIMAG\AppData\Local\Temp\tmpaffhab1s.pyomo.lp:21496: warning: lower bound of variable 'x1730' redefined
# C:\Users\UNIMAG\AppData\Local\Temp\tmpaffhab1s.pyomo.lp:21496: warning: upper bound of variable 'x1730' redefined
# 2184 rows, 3492 columns, 8814 non-zeros
# 900 integer variables, all of which are binary
# 22396 lines were read
# Writing problem data to 'C:\Users\UNIMAG\AppData\Local\Temp\tmpopgcecj9.glpk.glp'...
# 21825 lines were written
# GLPK Integer Optimizer, v4.65
# 2184 rows, 3492 columns, 8814 non-zeros
# 900 integer variables, all of which are binary
# Preprocessing...
# 36 constraint coefficient(s) were reduced
# 1428 rows, 2730 columns, 6540 non-zeros
# 900 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  5.000e+04  ratio =  5.000e+04
# GM: min|aij| =  6.575e-01  max|aij| =  1.521e+00  ratio =  2.313e+00
# EQ: min|aij| =  4.361e-01  max|aij| =  1.000e+00  ratio =  2.293e+00
# 2N: min|aij| =  2.930e-01  max|aij| =  1.416e+00  ratio =  4.833e+00
# Constructing initial basis...
# Size of triangular part is 1428
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 1428 rows, 2730 columns, 6540 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (860)
# *  1319: obj =   6.409981593e+08 inf =   2.207e-11 (0) 3
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +  1319: mip =     not found yet <=              +inf        (1; 0)
# +  1440: >>>>>   6.136969486e+08 <=   6.367785043e+08   3.8% (35; 0)
# +  3951: >>>>>   6.143854340e+08 <=   6.245692034e+08   1.7% (369; 68)
# +  4259: >>>>>   6.149696739e+08 <=   6.227676052e+08   1.3% (348; 169)
# +  5048: >>>>>   6.169687077e+08 <=   6.208577451e+08   0.6% (301; 317)
# +  5078: >>>>>   6.175529476e+08 <=   6.207578960e+08   0.5% (179; 572)
# +  5738: mip =   6.175529476e+08 <=     tree is empty   0.0% (0; 1113)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   6.0 secs
# Memory used: 4.5 Mb (4764466 bytes)
# Writing MIP solution to 'C:\Users\UNIMAG\AppData\Local\Temp\tmpembma3ay.glpk.raw'...
# 5685 lines were written
# Estado del solver: ok
# Condición de terminación: optimal

# %% [markdown]
# ### 10. Imprime los resultados

# %%
# Crear un diccionario para almacenar los resultados
resultados = {}

# Imprimir el valor de la función objetivo solo si la solución es óptima
if solucion.solver.status == pyo.SolverStatus.ok and solucion.solver.termination_condition == pyo.TerminationCondition.optimal:
    beneficio_total = pyo.value(instancia_modelo.objetivo)
    print("Beneficio total de distribución =", beneficio_total)
    resultados["BeneficioTotal"] = beneficio_total
else:
    print("El modelo no se resolvió de manera óptima. Verifica tu modelo o los datos de entrada.")
    resultados["Estado"] = "No Óptimo"

# Almacenar valores de variables en el diccionario de resultados
for v in instancia_modelo.component_objects(pyo.Var, active=True):
    for index in v:
        resultados[f"Valor_{str(v)}_{index}"] = pyo.value(v[index])

# Guardar resultados en un DataFrame
resultados_df = pd.DataFrame([resultados])

# Guardar resultados en un archivo Excel
resultados_df.to_excel('resultados_modelo_maximizacion.xlsx', index=False)
print("Resultados guardados en 'resultados_modelo_maximizacion.xlsx'")
# Out:
# Beneficio total de distribución = 617552947.643425
# Resultados guardados en 'resultados_modelo_maximizacion.xlsx'

# %%
# Crear un diccionario para almacenar los resultados de variables en DataFrames
resultados_dataframes = {}


############################################################################
# Imprimir valores de las variables de decisión y almacenarlos en DataFrames
for v in instancia_modelo.component_objects(pyo.Var, active=True):
    indices = []
    valores = []
    for index in v:
        indices.append(index)
        valores.append(pyo.value(v[index]))

    resultados_df = pd.DataFrame({f"{str(v)}_{index}": valor for index, valor in zip(indices, valores)}, index=[0])
    resultados_dataframes[str(v)] = resultados_df

    # Imprimir el DataFrame con los valores de la variable
    print(f"\nValores de la variable {str(v)}:")
    print(resultados_df)

# Guardar DataFrames de resultados en archivos Excel
for nombre_variable, df_resultado in resultados_dataframes.items():
    df_resultado.to_excel(f'resultados_{nombre_variable}.xlsx', index=False)
    print(f"Resultados de {nombre_variable} guardados en 'resultados_{nombre_variable}.xlsx'")


# Guardar DataFrames de resultados en archivos Excel
for nombre_variable, df_resultado in resultados_dataframes.items():
    df_resultado.to_csv(f'resultados_{nombre_variable}.csv', index=False)
    print(f"Resultados de {nombre_variable} guardados en 'resultados_{nombre_variable}.csv'")


################################################################################
# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
resultados_AC_df = pd.read_csv('resultados_AC.csv', delimiter=',', decimal='.')

# Extraer las columnas de productos y tiempos usando expresiones regulares
productos_cacopios_clientes_tiempos = resultados_AC_df.columns.str.extract(r"AC_\('\s*([^']+)\s*', '([^']+)', '([^']+)', (\d+)")

# Asignar nombres a las columnas
productos_cacopios_clientes_tiempos.columns = ['Productos', 'CAcopios', 'Clientes', 'Tiempo']

# Transponer el DataFrame para que las columnas sean correctas
resultados_AC_df_transpuesto = resultados_AC_df.transpose()

# Restablecer el índice
resultados_AC_df_transpuesto = resultados_AC_df_transpuesto.reset_index()

# Unir con las columnas de productos y tiempos
resultados_AC_df_melted = pd.concat([productos_cacopios_clientes_tiempos, resultados_AC_df_transpuesto], axis=1)

# Renombrar la columna '0' a 'Valor'
resultados_AC_df_melted = resultados_AC_df_melted.rename(columns={0: 'AC'})

# Eliminar la columna 'index'
resultados_AC_df_melted = resultados_AC_df_melted.drop(columns=['index'])

# Mostrar el DataFrame derretido
print(resultados_AC_df_melted)

# Guardar los tiempos en un archivo CSV
resultados_AC_df_melted.to_csv('resultados_AC_melted.csv', index=False)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo EXCEL
resultados_AC_df_melted.to_excel('resultados_AC_melted.xlsx', index=False)

################################################################################

# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
resultados_CA_df = pd.read_csv('resultados_CA.csv', delimiter=',', decimal='.')

# Extraer las columnas de nombre, ubicación y número usando expresiones regulares
cacopios_tiempo = resultados_CA_df.columns.str.extract(r"CA_\('\s*([^']+)\s*', (\d+)")

# Asignar nombres a las columnas
cacopios_tiempo.columns = ['CAcopios', 'Tiempo']

# Transponer el DataFrame para que las columnas sean correctas
resultados_CA_df_transpuesto = resultados_CA_df.transpose()

# Restablecer el índice
resultados_CA_df_transpuesto = resultados_CA_df_transpuesto.reset_index()

# Unir con las columnas de nombre, ubicación y número
resultados_CA_df_melted = pd.concat([cacopios_tiempo, resultados_CA_df_transpuesto], axis=1)

# Renombrar la columna '0' a 'CA'
resultados_CA_df_melted = resultados_CA_df_melted.rename(columns={0: 'CA'})

# Eliminar la columna 'index'
resultados_CA_df_melted = resultados_CA_df_melted.drop(columns=['index'])

# Mostrar el DataFrame derretido
print(resultados_CA_df_melted)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo CSV
resultados_CA_df_melted.to_csv('resultados_CA_melted.csv', index=False)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo EXCEL
resultados_CA_df_melted.to_excel('resultados_CA_melted.xlsx', index=False)

################################################################################

# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
resultados_AS_df = pd.read_csv('resultados_AS.csv', delimiter=',', decimal='.')

# Extraer las columnas de nombre, ubicación y número usando expresiones regulares
productores_cacopios_tiempo = resultados_AS_df.columns.str.extract(r"AS_\('\s*([^']+)\s*', '([^']+)', (\d+)")

# Asignar nombres a las columnas
productores_cacopios_tiempo.columns = ['Productores', 'CAcopios', 'Tiempo']

# Transponer el DataFrame para que las columnas sean correctas
resultados_AS_df_transpuesto = resultados_AS_df.transpose()

# Restablecer el índice
resultados_AS_df_transpuesto = resultados_AS_df_transpuesto.reset_index()

# Unir con las columnas de nombre, ubicación y número
resultados_AS_df_melted = pd.concat([productores_cacopios_tiempo, resultados_AS_df_transpuesto], axis=1)

# Renombrar la columna '0' a 'AS'
resultados_AS_df_melted = resultados_AS_df_melted.rename(columns={0: 'AS'})

# Eliminar la columna 'index'
resultados_AS_df_melted = resultados_AS_df_melted.drop(columns=['index'])

# Mostrar el DataFrame derretido
print(resultados_AS_df_melted)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo CSV
resultados_AS_df_melted.to_csv('resultados_AS_melted.csv', index=False)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo EXCEL
resultados_AS_df_melted.to_excel('resultados_AS_melted.xlsx', index=False)

################################################################################
# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
resultados_AC_df = pd.read_csv('resultados_PA.csv', delimiter=',', decimal='.')

# Extraer las columnas de productos y tiempos usando expresiones regulares
productos_productores_cacopios_tiempos = resultados_AC_df.columns.str.extract(r"PA_\('\s*([^']+)\s*', '([^']+)', '([^']+)', (\d+)")

# Asignar nombres a las columnas
productos_productores_cacopios_tiempos.columns = ['Productos', 'Productores', 'CAcopios', 'Tiempo']

# Transponer el DataFrame para que las columnas sean correctas
resultados_AC_df_transpuesto = resultados_AC_df.transpose()

# Restablecer el índice
resultados_AC_df_transpuesto = resultados_AC_df_transpuesto.reset_index()

# Unir con las columnas de productos y tiempos
resultados_AC_df_melted = pd.concat([productos_productores_cacopios_tiempos, resultados_AC_df_transpuesto], axis=1)

# Renombrar la columna '0' a 'Valor'
resultados_AC_df_melted = resultados_AC_df_melted.rename(columns={0: 'PA'})

# Eliminar la columna 'index'
resultados_AC_df_melted = resultados_AC_df_melted.drop(columns=['index'])

# Mostrar el DataFrame derretido
print(resultados_AC_df_melted)

# Guardar los tiempos en un archivo CSV
resultados_AC_df_melted.to_csv('resultados_PA_melted.csv', index=False)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo EXCEL
resultados_AC_df_melted.to_excel('resultados_PA_melted.xlsx', index=False)

################################################################################
# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
resultados_InvCA_df = pd.read_csv('resultados_InvCA.csv', delimiter=',', decimal='.')

# Extraer las columnas de nombre, ubicación y número usando expresiones regulares
productos_cacopios_tiempo = resultados_InvCA_df.columns.str.extract(r"InvCA_\('\s*([^']+)\s*', '([^']+)', (\d+)")

# Asignar nombres a las columnas
productos_cacopios_tiempo.columns = ['Productos', 'CAcopios', 'Tiempo']

# Transponer el DataFrame para que las columnas sean correctas
resultados_InvCA_df_transpuesto = resultados_InvCA_df.transpose()

# Restablecer el índice
resultados_InvCA_df_transpuesto = resultados_InvCA_df_transpuesto.reset_index()

# Unir con las columnas de nombre, ubicación y número
resultados_InvCA_df_melted = pd.concat([productos_cacopios_tiempo, resultados_InvCA_df_transpuesto], axis=1)

# Renombrar la columna '0' a 'AS'
resultados_InvCA_df_melted = resultados_InvCA_df_melted.rename(columns={0: 'InvCA'})

# Eliminar la columna 'index'
resultados_InvCA_df_melted = resultados_InvCA_df_melted.drop(columns=['index'])

# Mostrar el DataFrame derretido
print(resultados_InvCA_df_melted)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo CSV
resultados_InvCA_df_melted.to_csv('resultados_InvCA_melted.csv', index=False)

# Guardar el DataFrame derretido con la columna renombrada en un nuevo archivo EXCEL
resultados_InvCA_df_melted.to_excel('resultados_InvCA_melted.xlsx', index=False)
# Out:
# Valores de la variable CA:
#    CA_('Guamal', 1)  CA_('Guamal', 2)  CA_('Guamal', 3)  CA_('Guamal', 4)  \
# 0               0.0               1.0               1.0               1.0
#
#    CA_('Guamal', 5)  CA_('Guamal', 6)  CA_('Guamal', 7)  CA_('Guamal', 8)  \
# 0               1.0               1.0               1.0               1.0
#
#    CA_('Guamal', 9)  CA_('Guamal', 10)  ...  CA_('Nueva granada', 3)  \
# 0               1.0                1.0  ...                      1.0
#
#    CA_('Nueva granada', 4)  CA_('Nueva granada', 5)  CA_('Nueva granada', 6)  \
# 0                      1.0                      1.0                      1.0
#
#    CA_('Nueva granada', 7)  CA_('Nueva granada', 8)  CA_('Nueva granada', 9)  \
# 0                      1.0                      1.0                      1.0
#
#    CA_('Nueva granada', 10)  CA_('Nueva granada', 11)  \
# 0                       1.0                       1.0
#
#    CA_('Nueva granada', 12)
# 0                       1.0
#
# [1 rows x 36 columns]
#
# Valores de la variable AS:
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 1)  \
# 0                                      0.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 2)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 3)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 4)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 5)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 6)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 7)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 8)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 9)  \
# 0                                      1.0
#
#    AS_('LUIS GALVIS NAVARRO', 'Guamal', 10)  ...  \
# 0                                       1.0  ...
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 3)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 4)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 5)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 6)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 7)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 8)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 9)  \
# 0                                         1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 10)  \
# 0                                          1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 11)  \
# 0                                          1.0
#
#    AS_('ARTURO CARBACHO', 'Nueva granada', 12)
# 0                                          1.0
#
# [1 rows x 864 columns]
#
# Valores de la variable PA:
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 1)  \
# 0                                                0.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 2)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 3)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 4)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 5)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 6)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 7)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 8)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 9)  \
# 0                                            33900.0
#
#    PA_('Queso duro', 'LUIS GALVIS NAVARRO', 'Guamal', 10)  ...  \
# 0                                            33900.0       ...
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 3)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 4)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 5)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 6)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 7)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 8)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 9)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 10)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 11)  \
# 0                                             1450.0
#
#    PA_('Queso blando', 'ARTURO CARBACHO', 'Nueva granada', 12)
# 0                                             1450.0
#
# [1 rows x 1728 columns]
#
# Valores de la variable AC:
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 1)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 2)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 3)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 4)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 5)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 6)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 7)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 8)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 9)  \
# 0                                            0.0
#
#    AC_('Queso duro', 'Guamal', 'Santa Marta', 10)  ...  \
# 0                                             0.0  ...
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 3)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 4)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 5)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 6)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 7)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 8)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 9)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 10)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 11)  \
# 0                                                0.0
#
#    AC_('Queso blando', 'Nueva granada', 'Valledupar', 12)
# 0                                                0.0
#
# [1 rows x 792 columns]
#
# Valores de la variable InvCA:
#    InvCA_('Queso duro', 'Guamal', 1)  InvCA_('Queso duro', 'Guamal', 2)  \
# 0                                0.0                                0.0
#
#    InvCA_('Queso duro', 'Guamal', 3)  InvCA_('Queso duro', 'Guamal', 4)  \
# 0                                0.0                                0.0
#
#    InvCA_('Queso duro', 'Guamal', 5)  InvCA_('Queso duro', 'Guamal', 6)  \
# 0                                0.0                                0.0
#
#    InvCA_('Queso duro', 'Guamal', 7)  InvCA_('Queso duro', 'Guamal', 8)  \
# 0                                0.0                                0.0
#
#    InvCA_('Queso duro', 'Guamal', 9)  InvCA_('Queso duro', 'Guamal', 10)  ...  \
# 0                                0.0                                 0.0  ...
#
#    InvCA_('Queso blando', 'Nueva granada', 3)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 4)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 5)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 6)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 7)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 8)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 9)  \
# 0                                         0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 10)  \
# 0                                          0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 11)  \
# 0                                          0.0
#
#    InvCA_('Queso blando', 'Nueva granada', 12)
# 0                                         -0.0
#
# [1 rows x 72 columns]
# Resultados de CA guardados en 'resultados_CA.xlsx'
# Resultados de AS guardados en 'resultados_AS.xlsx'
# Resultados de PA guardados en 'resultados_PA.xlsx'
# Resultados de AC guardados en 'resultados_AC.xlsx'
# Resultados de InvCA guardados en 'resultados_InvCA.xlsx'
# Resultados de CA guardados en 'resultados_CA.csv'
# Resultados de AS guardados en 'resultados_AS.csv'
# Resultados de PA guardados en 'resultados_PA.csv'
# Resultados de AC guardados en 'resultados_AC.csv'
# Resultados de InvCA guardados en 'resultados_InvCA.csv'
#         Productos       CAcopios     Clientes Tiempo   AC
# 0      Queso duro         Guamal  Santa Marta      1  0.0
# 1      Queso duro         Guamal  Santa Marta      2  0.0
# 2      Queso duro         Guamal  Santa Marta      3  0.0
# 3      Queso duro         Guamal  Santa Marta      4  0.0
# 4      Queso duro         Guamal  Santa Marta      5  0.0
# ..            ...            ...          ...    ...  ...
# 787  Queso blando  Nueva granada   Valledupar      8  0.0
# 788  Queso blando  Nueva granada   Valledupar      9  0.0
# 789  Queso blando  Nueva granada   Valledupar     10  0.0
# 790  Queso blando  Nueva granada   Valledupar     11  0.0
# 791  Queso blando  Nueva granada   Valledupar     12  0.0
#
# [792 rows x 5 columns]
#          CAcopios Tiempo   CA
# 0          Guamal      1  0.0
# 1          Guamal      2  1.0
# 2          Guamal      3  1.0
# 3          Guamal      4  1.0
# 4          Guamal      5  1.0
# 5          Guamal      6  1.0
# 6          Guamal      7  1.0
# 7          Guamal      8  1.0
# 8          Guamal      9  1.0
# 9          Guamal     10  1.0
# 10         Guamal     11  1.0
# 11         Guamal     12  1.0
# 12        Pivijay      1  0.0
# 13        Pivijay      2  0.0
# 14        Pivijay      3  0.0
# 15        Pivijay      4  0.0
# 16        Pivijay      5  0.0
# 17        Pivijay      6  0.0
# 18        Pivijay      7  0.0
# 19        Pivijay      8  0.0
# 20        Pivijay      9  0.0
# 21        Pivijay     10  0.0
# 22        Pivijay     11  0.0
# 23        Pivijay     12  0.0
# 24  Nueva granada      1  0.0
# 25  Nueva granada      2  0.0
# 26  Nueva granada      3  1.0
# 27  Nueva granada      4  1.0
# 28  Nueva granada      5  1.0
# 29  Nueva granada      6  1.0
# 30  Nueva granada      7  1.0
# 31  Nueva granada      8  1.0
# 32  Nueva granada      9  1.0
# 33  Nueva granada     10  1.0
# 34  Nueva granada     11  1.0
# 35  Nueva granada     12  1.0
#              Productores       CAcopios Tiempo   AS
# 0    LUIS GALVIS NAVARRO         Guamal      1  0.0
# 1    LUIS GALVIS NAVARRO         Guamal      2  1.0
# 2    LUIS GALVIS NAVARRO         Guamal      3  1.0
# 3    LUIS GALVIS NAVARRO         Guamal      4  1.0
# 4    LUIS GALVIS NAVARRO         Guamal      5  1.0
# ..                   ...            ...    ...  ...
# 859      ARTURO CARBACHO  Nueva granada      8  1.0
# 860      ARTURO CARBACHO  Nueva granada      9  1.0
# 861      ARTURO CARBACHO  Nueva granada     10  1.0
# 862      ARTURO CARBACHO  Nueva granada     11  1.0
# 863      ARTURO CARBACHO  Nueva granada     12  1.0
#
# [864 rows x 4 columns]
#          Productos          Productores       CAcopios Tiempo       PA
# 0       Queso duro  LUIS GALVIS NAVARRO         Guamal      1      0.0
# 1       Queso duro  LUIS GALVIS NAVARRO         Guamal      2  33900.0
# 2       Queso duro  LUIS GALVIS NAVARRO         Guamal      3  33900.0
# 3       Queso duro  LUIS GALVIS NAVARRO         Guamal      4  33900.0
# 4       Queso duro  LUIS GALVIS NAVARRO         Guamal      5  33900.0
# ...            ...                  ...            ...    ...      ...
# 1723  Queso blando      ARTURO CARBACHO  Nueva granada      8   1450.0
# 1724  Queso blando      ARTURO CARBACHO  Nueva granada      9   1450.0
# 1725  Queso blando      ARTURO CARBACHO  Nueva granada     10   1450.0
# 1726  Queso blando      ARTURO CARBACHO  Nueva granada     11   1450.0
# 1727  Queso blando      ARTURO CARBACHO  Nueva granada     12   1450.0
#
# [1728 rows x 5 columns]
#        Productos       CAcopios Tiempo  InvCA
# 0     Queso duro         Guamal      1    0.0
# 1     Queso duro         Guamal      2    0.0
# 2     Queso duro         Guamal      3    0.0
# 3     Queso duro         Guamal      4    0.0
# 4     Queso duro         Guamal      5    0.0
# ..           ...            ...    ...    ...
# 67  Queso blando  Nueva granada      8    0.0
# 68  Queso blando  Nueva granada      9    0.0
# 69  Queso blando  Nueva granada     10    0.0
# 70  Queso blando  Nueva granada     11    0.0
# 71  Queso blando  Nueva granada     12   -0.0
#
# [72 rows x 4 columns]

# %%
# Resolver el problema
solucion = pyo.SolverFactory('glpk').solve(instancia_modelo, tee=True)

# Verificar si la solución es óptima
if solucion.solver.status == pyo.SolverStatus.ok and solucion.solver.termination_condition == pyo.TerminationCondition.optimal:
    # Cargar valores óptimos en las variables
    instancia_modelo.solutions.load_from(solucion)


    # Crear listas para almacenar datos por período de tiempo
    ingresos_por_periodo = []
    costos_por_periodo = []
    costos_por_produccion_periodo = []
    costos_por_operacion_periodo = []
    costos_por_fijo_operacion_periodo = []
    costos_por_variable_operacion_periodo = []
    costos_por_inventario_acopio_periodo = []
    costos_por_transporte_periodo = []
    costos_por_transporte_productor_acopio_periodo = []
    costos_por_transporte_acopio_cliente_periodo = []
    beneficios_por_periodo = []

    # Imprimir y guardar totales por período
    for t in instancia_modelo.periodo_de_tiempo:
        ingresos_totales_t = sum(
            instancia_modelo.Precio[p, t] * instancia_modelo.PA[p, i, j, t].value
            for p in instancia_modelo.productos
            for i in instancia_modelo.productores
            for j in instancia_modelo.centros_de_acopios
        )
        costos_totales_t = (
            sum(
                instancia_modelo.CostoProduccion[p, i, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoFijoAcopio[j, t] * instancia_modelo.CA[j, t].value
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoVarAcopio[p, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoInvAcopio[p, j, t] * instancia_modelo.InvCA[p, j, t].value
                for p in instancia_modelo.productos
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoTransProdAcopio[p, i, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoTransAcopioClie[p, j, k, t] * instancia_modelo.AC[p, j, k, t].value
                for p in instancia_modelo.productos
                for j in instancia_modelo.centros_de_acopios
                for k in instancia_modelo.clientes
            )
        )
        costos_produccion_t = (
            sum(
                instancia_modelo.CostoProduccion[p, i, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
        )
        costos_operacion_t = (
            sum(
                instancia_modelo.CostoFijoAcopio[j, t] * instancia_modelo.CA[j, t].value
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoVarAcopio[p, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
        )        
        costos_fij_operacion_t = (
            sum(
                instancia_modelo.CostoFijoAcopio[j, t] * instancia_modelo.CA[j, t].value
                for j in instancia_modelo.centros_de_acopios
            )
        )           
        costos_variable_operacion_t = (
            sum(
                instancia_modelo.CostoVarAcopio[p, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
        )         
        costos_inventario_acopio_t = (
            sum(
                instancia_modelo.CostoInvAcopio[p, j, t] * instancia_modelo.InvCA[p, j, t].value
                for p in instancia_modelo.productos
                for j in instancia_modelo.centros_de_acopios
            )
        )                
        costos_transporte_t = (
            + sum(
                instancia_modelo.CostoTransProdAcopio[p, i, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
            + sum(
                instancia_modelo.CostoTransAcopioClie[p, j, k, t] * instancia_modelo.AC[p, j, k, t].value
                for p in instancia_modelo.productos
                for j in instancia_modelo.centros_de_acopios
                for k in instancia_modelo.clientes
            )
        )                
        costos_transporte_productor_acopio_t = (
            sum(
                instancia_modelo.CostoTransProdAcopio[p, i, j, t] * instancia_modelo.PA[p, i, j, t].value
                for p in instancia_modelo.productos
                for i in instancia_modelo.productores
                for j in instancia_modelo.centros_de_acopios
            )
        )  
        costos_transporte_acopio_cliente_t = (
            sum(
                instancia_modelo.CostoTransAcopioClie[p, j, k, t] * instancia_modelo.AC[p, j, k, t].value
                for p in instancia_modelo.productos
                for j in instancia_modelo.centros_de_acopios
                for k in instancia_modelo.clientes
            )
        )   
        beneficios_totales_t = ingresos_totales_t - costos_totales_t

        # Guardar datos en las listas
        ingresos_por_periodo.append(ingresos_totales_t)
        costos_por_periodo.append(costos_totales_t)
        costos_por_produccion_periodo.append(costos_produccion_t) 
        costos_por_operacion_periodo.append(costos_operacion_t)
        costos_por_fijo_operacion_periodo.append(costos_fij_operacion_t)
        costos_por_variable_operacion_periodo.append(costos_variable_operacion_t)
        costos_por_inventario_acopio_periodo.append(costos_inventario_acopio_t)
        costos_por_transporte_periodo.append(costos_transporte_t)
        costos_por_transporte_productor_acopio_periodo.append(costos_transporte_productor_acopio_t)
        costos_por_transporte_acopio_cliente_periodo.append(costos_transporte_acopio_cliente_t)
        beneficios_por_periodo.append(beneficios_totales_t)


    # Crear DataFrame con los datos
    dataframe_resultados = pd.DataFrame({
        "Periodo": instancia_modelo.periodo_de_tiempo,
        "Ingresos": ingresos_por_periodo,
        "Costos": costos_por_periodo,
        "Costos Produccion": costos_por_produccion_periodo,
        "Costos Operacion": costos_por_operacion_periodo,
        "Costos Fijos Operacion": costos_por_fijo_operacion_periodo,
        "Costos Variables Operacion": costos_por_variable_operacion_periodo,
        "Costos Inventario": costos_por_inventario_acopio_periodo,
        "Costos Transporte": costos_por_transporte_periodo,
        "Costos Transportes del Productor al Centro de Acopio": costos_por_transporte_productor_acopio_periodo,
        "Costos Transportes del Centro de Acopio al cliente": costos_por_transporte_acopio_cliente_periodo,
        "Beneficios": beneficios_por_periodo
    })

    # Guardar resultados en un archivo Excel
    archivo_excel = 'resultados_por_periodo.xlsx'
    dataframe_resultados.to_excel(archivo_excel, index=False)

    print(f"Resultados guardados en '{archivo_excel}'.")
else:
    print("El modelo no se resolvió de manera óptima. Verifica tu modelo o los datos de entrada.")
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\UNIMAG\AppData\Local\Temp\tmph9fk_vzv.glpk.raw --wglp C:\Users\UNIMAG\AppData\Local\Temp\tmpf5ooii06.glpk.glp
#  --cpxlp C:\Users\UNIMAG\AppData\Local\Temp\tmpe33obdsm.pyomo.lp
# Reading problem data from 'C:\Users\UNIMAG\AppData\Local\Temp\tmpe33obdsm.pyomo.lp'...
# C:\Users\UNIMAG\AppData\Local\Temp\tmpe33obdsm.pyomo.lp:21496: warning: lower bound of variable 'x1730' redefined
# C:\Users\UNIMAG\AppData\Local\Temp\tmpe33obdsm.pyomo.lp:21496: warning: upper bound of variable 'x1730' redefined
# 2184 rows, 3492 columns, 8814 non-zeros
# 900 integer variables, all of which are binary
# 22396 lines were read
# Writing problem data to 'C:\Users\UNIMAG\AppData\Local\Temp\tmpf5ooii06.glpk.glp'...
# 21825 lines were written
# GLPK Integer Optimizer, v4.65
# 2184 rows, 3492 columns, 8814 non-zeros
# 900 integer variables, all of which are binary
# Preprocessing...
# 36 constraint coefficient(s) were reduced
# 1428 rows, 2730 columns, 6540 non-zeros
# 900 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  5.000e+04  ratio =  5.000e+04
# GM: min|aij| =  6.575e-01  max|aij| =  1.521e+00  ratio =  2.313e+00
# EQ: min|aij| =  4.361e-01  max|aij| =  1.000e+00  ratio =  2.293e+00
# 2N: min|aij| =  2.930e-01  max|aij| =  1.416e+00  ratio =  4.833e+00
# Constructing initial basis...
# Size of triangular part is 1428
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 1428 rows, 2730 columns, 6540 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (860)
# *  1319: obj =   6.409981593e+08 inf =   2.207e-11 (0) 3
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +  1319: mip =     not found yet <=              +inf        (1; 0)
# +  1440: >>>>>   6.136969486e+08 <=   6.367785043e+08   3.8% (35; 0)
# +  3951: >>>>>   6.143854340e+08 <=   6.245692034e+08   1.7% (369; 68)
# +  4259: >>>>>   6.149696739e+08 <=   6.227676052e+08   1.3% (348; 169)
# +  5048: >>>>>   6.169687077e+08 <=   6.208577451e+08   0.6% (301; 317)
# +  5078: >>>>>   6.175529476e+08 <=   6.207578960e+08   0.5% (179; 572)
# +  5738: mip =   6.175529476e+08 <=     tree is empty   0.0% (0; 1113)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   5.3 secs
# Memory used: 4.5 Mb (4764466 bytes)
# Writing MIP solution to 'C:\Users\UNIMAG\AppData\Local\Temp\tmph9fk_vzv.glpk.raw'...
# 5685 lines were written
# Resultados guardados en 'resultados_por_periodo.xlsx'.

# %% [markdown]
# ### 10. Imprime los resultados

# %% [markdown]
# # SOLUCIÓN DEL MODELO DE TRANSPORTE MEDIANTE ITERACION DEL MODELO

# %% [markdown]
# 1. **`modelo` (clase)**
#    - **Descripción:** Define la clase `modelo` que actúa como un modelo abstracto de Pyomo. En esta clase se definen conjuntos, parámetros, variables, restricciones y la función objetivo.
#    - **Uso:** Es la base del modelo y se utiliza para crear instancias específicas del modelo.
#
# 2. **Carga de Datos**
#    - **Descripción:** Bloque de código que carga datos desde archivos CSV en DataFrames de pandas y luego convierte estos DataFrames en diccionarios para ser utilizados como parámetros en el modelo.
#    - **Uso:** Prepara los datos necesarios para definir conjuntos y parámetros del modelo.
#
# 3. **Definición de Conjuntos y Parámetros**
#    - **Descripción:** Bloque de código que utiliza las clases y métodos de Pyomo para definir conjuntos y parámetros del modelo, basándose en los datos cargados.
#    - **Uso:** Establece las bases del modelo utilizando los conjuntos y parámetros definidos.
#
# 4. **Definición de Variables**
#    - **Descripción:** Bloque de código que utiliza las clases y métodos de Pyomo para definir las variables de decisión del modelo (por ejemplo, `modelo.CA`, `modelo.AS`, etc.).
#    - **Uso:** Introduce las variables que el modelo utilizará para encontrar soluciones.
#
# 5. **Definición de Restricciones**
#    - **Descripción:** Bloque de código que utiliza las clases y métodos de Pyomo para definir restricciones en el modelo.
#    - **Uso:** Establece las restricciones que deben cumplirse para que la solución sea válida.
#
# 6. **Definición de la Función Objetivo**
#    - **Descripción:** Bloque de código que utiliza las clases y métodos de Pyomo para definir la función objetivo del modelo, que se busca minimizar.
#    - **Uso:** Define la función que se optimizará durante la resolución del modelo.
#
# 7. **Resolución del Modelo (bucle principal)**
#    - **Descripción:** Bloque de código que resuelve el modelo utilizando el solver GLPK en un bucle iterativo. Luego, almacena y presenta los resultados obtenidos.
#    - **Uso:** Realiza la optimización del modelo y presenta los resultados después de cada iteración.

# %% [markdown]
# El modelo reoptimizado utiliza la respuesta inicial para calcular de manera más eficiente las variables de decisión. Al obtener una solución inicial, el modelo ajustado recalcula el valor óptimo de la función objetivo. Además, proporciona una salida de datos más detallada y precisa específicamente para las variables de decisión. Esto resulta en una toma de decisiones más precisa y fundamentada, ya que la salida de datos refleja una iteración mejorada del modelo original.
#
# Este modelo realiza una simulación 100 resultados optimos con el fin de estimar la eficiencia del software. Determina lun grafico de probabilidad de los datos con un prueba KS con Valor-P de normalidad.

# %% [markdown]
# # Analisis estadistico de la distribucion de probabilidad del tiempo de iteraciones
#
# La prueba de Kolmogorov-Smirnov (KS) desempeña un papel crucial al determinar si existe suficiente evidencia estadística para rechazar la hipótesis nula, la cual afirma que la muestra sigue la distribución teórica dada. Este análisis se basa en el valor p obtenido a partir de la prueba KS. Si dicho valor p resulta ser menor que un nivel de significancia predefinido, como 0.05, se rechaza la hipótesis nula. En consecuencia, se sugiere que existen diferencias estadísticamente significativas entre la muestra y la distribución teórica propuesta.
#
# **Hipótesis Nula $H_{0}$:**
#
# $H_{0}$: La muestra sigue la misma distribución que la distribución teórica especificada.
#
# **Hipótesis Alternativa $H_{1}$:**
#
# $H_{1}$: La muestra no sigue la misma distribución que la distribución teórica especificada.
#
# En el contexto específico del código proporcionado, la prueba KS se emplea para evaluar la calidad del ajuste de varias distribuciones a los datos de `tiempos_iteracion`. El resultado de la prueba se almacena en `best_kstest_result`, siendo el valor p el componente clave. Este valor p se compara con el nivel de significancia para determinar si existe suficiente evidencia para rechazar la hipótesis nula. En última instancia, el proceso permite identificar la distribución que mejor se ajusta a los datos proporcionados.

# %% [markdown]
# # Análisis de Distribuciones de Tiempos de Iteración
#
# En este análisis, se exploran y comparan diversas distribuciones estadísticas para modelar los tiempos de iteración de un proceso. El código utiliza la prueba de Kolmogorov-Smirnov (KS) para evaluar la bondad de ajuste de diferentes distribuciones a los datos observados.
#
# ## Carga de Datos
#
# El conjunto de datos se carga desde un archivo CSV llamado `tiempos_iteraciones.csv`. La columna de interés, `TiempoIteracion`, se extrae para su posterior análisis.
#
# ## Estilo de Gráficos
#
# Se aplica el estilo `ggplot` a los gráficos para una presentación estética y coherente.
#
# ## Distribuciones y Parámetros
#
# Se define un conjunto de distribuciones estadísticas junto con sus parámetros asociados. Estas distribuciones incluyen la normal, exponencial, log-normal, entre otras.
#
# ## Mejor Ajuste
#
# El código ajusta los datos a cada distribución y utiliza la prueba KS para evaluar la bondad de ajuste. Se almacenan los resultados para todas las distribuciones y se identifica la distribución que mejor se ajusta según la prueba KS.
#
# ## Resultados
#
# Se imprimen los resultados, mostrando la distribución que proporciona el mejor ajuste, junto con los parámetros estimados y el valor p de la prueba KS.
#
# ## Visualización
#
# Se genera un histograma de los tiempos de iteración y se superponen las curvas de densidad de probabilidad de las distribuciones evaluadas. Esto proporciona una representación visual de cómo se ajustan las distribuciones a los datos.
#
# ## Guardar Resultados y Gráfico
#
# Los resultados se guardan en un archivo CSV llamado `resultados_distribuciones_probabilidad.csv`. Además, se guarda un gráfico que muestra el histograma y las curvas de las distribuciones en un archivo PNG llamado `histograma_tiempos_mejor_ajuste_y_distribuciones.png`.
#
# ## Conclusión
#
# Este análisis brinda información sobre qué distribución se ajusta mejor a los tiempos de iteración, proporcionando una base para comprender la naturaleza de los datos observados.

# %%
import time

# Definir el número de iteraciones
num_iteraciones = 30

# Lista para almacenar tiempos transcurridos
tiempos_transcurridos = []

# Bucle de iteraciones
for iteracion in range(num_iteraciones):
    # Iniciar el temporizador
    inicio_tiempo = time.time()

    # Resolver el problema
    solucion = pyo.SolverFactory('glpk').solve(instancia_modelo)

    # Detener el temporizador
    fin_tiempo = time.time()

    # Calcular el tiempo transcurrido
    tiempo_transcurrido = fin_tiempo - inicio_tiempo

    # Almacenar el tiempo transcurrido en la lista
    tiempos_transcurridos.append(tiempo_transcurrido)

    # Imprimir el progreso de la iteración
    print(f"Iteración {iteracion + 1}/{num_iteraciones} completada. Tiempo transcurrido: {tiempo_transcurrido} segundos")

# Calcular estadísticas de tiempo
if tiempos_transcurridos:
    tiempo_promedio = sum(tiempos_transcurridos) / num_iteraciones
    tiempo_maximo = max(tiempos_transcurridos)
    tiempo_minimo = min(tiempos_transcurridos)

    # Guardar los tiempos en un archivo CSV
    tiempos_df = pd.DataFrame({"TiempoIteracion": tiempos_transcurridos})
    tiempos_df.to_csv('tiempos_iteraciones.csv', index=False)

    print("\nEstadísticas de tiempo:")
    print(f"Tiempo promedio: {tiempo_promedio} segundos")
    print(f"Tiempo máximo: {tiempo_maximo} segundos")
    print(f"Tiempo mínimo: {tiempo_minimo} segundos")
else:
    print("No se registraron tiempos transcurridos.")
# Out:
# Iteración 1/30 completada. Tiempo transcurrido: 5.167999267578125 segundos
# Iteración 2/30 completada. Tiempo transcurrido: 4.282030820846558 segundos
# Iteración 3/30 completada. Tiempo transcurrido: 5.953291893005371 segundos
# Iteración 4/30 completada. Tiempo transcurrido: 5.1564624309539795 segundos
# Iteración 5/30 completada. Tiempo transcurrido: 5.43859601020813 segundos
# Iteración 6/30 completada. Tiempo transcurrido: 3.8710079193115234 segundos
# Iteración 7/30 completada. Tiempo transcurrido: 4.782576322555542 segundos
# Iteración 8/30 completada. Tiempo transcurrido: 4.478883981704712 segundos
# Iteración 9/30 completada. Tiempo transcurrido: 3.7693228721618652 segundos
# Iteración 10/30 completada. Tiempo transcurrido: 4.088202714920044 segundos
# Iteración 11/30 completada. Tiempo transcurrido: 4.104360818862915 segundos
# Iteración 12/30 completada. Tiempo transcurrido: 3.9709627628326416 segundos
# Iteración 13/30 completada. Tiempo transcurrido: 3.854201078414917 segundos
# Iteración 14/30 completada. Tiempo transcurrido: 4.354792594909668 segundos
# Iteración 15/30 completada. Tiempo transcurrido: 4.054317474365234 segundos
# Iteración 16/30 completada. Tiempo transcurrido: 3.9713633060455322 segundos
# Iteración 17/30 completada. Tiempo transcurrido: 5.027324438095093 segundos
# Iteración 18/30 completada. Tiempo transcurrido: 5.583343744277954 segundos
# Iteración 19/30 completada. Tiempo transcurrido: 4.838608503341675 segundos
# Iteración 20/30 completada. Tiempo transcurrido: 4.00327205657959 segundos
# Iteración 21/30 completada. Tiempo transcurrido: 4.077057361602783 segundos
# Iteración 22/30 completada. Tiempo transcurrido: 4.084589958190918 segundos
# Iteración 23/30 completada. Tiempo transcurrido: 4.004382610321045 segundos
# Iteración 24/30 completada. Tiempo transcurrido: 4.090245723724365 segundos
# Iteración 25/30 completada. Tiempo transcurrido: 3.8725268840789795 segundos
# Iteración 26/30 completada. Tiempo transcurrido: 5.290932893753052 segundos
# Iteración 27/30 completada. Tiempo transcurrido: 3.8888497352600098 segundos
# Iteración 28/30 completada. Tiempo transcurrido: 3.7654364109039307 segundos
# Iteración 29/30 completada. Tiempo transcurrido: 3.559720516204834 segundos
# Iteración 30/30 completada. Tiempo transcurrido: 4.172971963882446 segundos
#
# Estadísticas de tiempo:
# Tiempo promedio: 4.385254502296448 segundos
# Tiempo máximo: 5.953291893005371 segundos
# Tiempo mínimo: 3.559720516204834 segundos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kstest, norm, expon, lognorm, weibull_min, gamma, erlang, triang, logistic, halfnorm, cauchy
from matplotlib import style

# Aplicar estilo ggplot
style.use('ggplot')

# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
file_path = 'tiempos_iteraciones.csv'
df = pd.read_csv(file_path)

# Extraer la columna de interés
tiempos_iteracion = df['TiempoIteracion']

# Definir el diccionario de descripciones de parámetros
param_descriptions = {
    'norm': 'Media y Desviación Estándar',
    'expon': 'Lambda (tasa)',
    'lognorm': 'Media logarítmica y Desviación Estándar logarítmica',
    'weibull_min': 'Parámetro de forma (c), loc, y scale',
    'gamma': 'Parámetro de forma (a), loc, y scale',
    'erlang': 'Parámetro de forma (k), loc, y scale',
    'triang': 'Valor mínimo, Valor máximo y Valor modal',
    'logistic': 'Media y Escala',
    'halfnorm': 'Media y Desviación Estándar',
    'cauchy': 'Media y Escala'
}

# Distribuciones para probar
distribuciones = {
    'norm': norm,
    'expon': expon,
    'lognorm': lognorm,
    'weibull_min': weibull_min,
    'gamma': gamma,
    'erlang': erlang,
    'triang': triang,
    'logistic': logistic,
    'halfnorm': halfnorm,
    'cauchy': cauchy
}

# Inicializar variables para el mejor ajuste
best_fit_name = None
best_fit_params = None
best_kstest_result = None
best_fit_curve = None

# Inicializar variables para almacenar información de todas las distribuciones
all_fit_results = []

# Iterar sobre las distribuciones y encontrar el mejor ajuste
for distribution_name, distribution in distribuciones.items():
    # Ajustar los datos a la distribución actual
    params = distribution.fit(tiempos_iteracion)
    
    # Realizar la prueba de ajuste de Kolmogorov-Smirnov
    kstest_result = kstest(tiempos_iteracion, distribution.cdf, params)
    
    # Almacenar información de la distribución actual
    fit_result = {
        'Distribution': distribution_name,
        'Parameters': params,
        'KS_pvalue': kstest_result.pvalue
    }
    all_fit_results.append(fit_result)
    
    # Actualizar el mejor ajuste si es necesario
    if best_fit_name is None or kstest_result.statistic < best_kstest_result.statistic:
        best_fit_name = distribution_name
        best_fit_params = params
        best_kstest_result = kstest_result
        best_fit_curve = distribution.pdf(np.linspace(min(tiempos_iteracion), max(tiempos_iteracion), 100), *params)

# Imprimir los resultados
print(f'Mejor ajuste: {best_fit_name}')
print(f'Parámetros estimados: {best_fit_params}')
print(f'Prueba KS p-value: {best_kstest_result.pvalue:.4f}')

# Crear un DataFrame con los resultados
results_df = pd.DataFrame(all_fit_results)

# Guardar los resultados en un archivo CSV
results_df.to_csv('resultados_distribuciones_probabilidad.csv', index=False)

# Visualizar histograma de los tiempos de iteración y gráficos para cada distribución
plt.hist(tiempos_iteracion, bins=20, density=True, alpha=0.5, color='g')

for fit_result in all_fit_results:
    distribution_name = fit_result['Distribution']
    params = fit_result['Parameters']
    p_value = fit_result['KS_pvalue']
    curve = distribuciones[distribution_name].pdf(np.linspace(min(tiempos_iteracion), max(tiempos_iteracion), 100), *params)
    
    plt.plot(np.linspace(min(tiempos_iteracion), max(tiempos_iteracion), 100), curve, label=f'{distribution_name} - p-value: {p_value:.4f}')

# Configuración del gráfico
plt.title(f'Tiempo de iteraciones en segundos\nMejor ajuste: {best_fit_name}\nPrueba KS p-value: {best_kstest_result.pvalue:.4f}')
plt.xlabel('Tiempo de Iteración (s)')
plt.ylabel('Frecuencia')
plt.legend()

# Guardar la imagen en un archivo PNG
plt.savefig('histograma_tiempos_distribuciones.png')

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.2.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.133333333333333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.033333333333333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.155555555555557.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.233333333333334.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.9777777777777787.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.866666666666669.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.08888888888889.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.022222222222222.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.048148148148151.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.076543209876547.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.062962962962966.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.751851851851856.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.7395061728395094.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.027572016460907.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.820781893004119.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.5550068587105645.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3010288065843643.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.5861454046639256.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3484453589391867.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.112277091906721.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.7996342021033387.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.266117969821673.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.5558146623990234.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.344121831021691.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8656683432403547.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.020770038442648.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.8394003285407026.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.766289578711465.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.433963412683627.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2299490128411836.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9057332589862028.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2259299889531636.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2289442568691786.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.7656197413967947.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1207048795888506.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.028550565636186.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8258441421124658.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0999739272953066.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8220310839918712.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.213599144264236.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.107377545208302.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.100713878018028.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.133044242777176.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1082415061657738.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2575948981226883.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0858116487578116.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.987354655823689.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0121210603607613.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9640608374582555.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9533837102356868.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0527046641272806.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.095407375372203.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9674043727635233.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.965210392935374.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.049048031080365.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8901387989437932.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8305586551445834.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9944256870964194.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9338731560636049.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9573760837174317.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.053769606570945.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9310465008505813.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9578380103180328.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9625051306732.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9061927897310555.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9723674627550785.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.997119283913226.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9475646966162423.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9642487763122491.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959094256866136.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9568458134851046.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9582606427821283.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9789168783193194.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9554027420420117.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9428042983717724.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9649766716592518.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9599991141227922.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597728998086281.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9618408995577996.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591557069760461.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9599171806429116.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9598811104343408.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9672729173377475.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9583702858659455.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9532947305249704.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9620561863756816.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.961049348141266.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959629117267351.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9601559492383112.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9600872395373186.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.956668242071395.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9607092002996098.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9619134188702412.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592560691170195.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9604058887019478.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9602116958432987.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9600307373026333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9589564678756908.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9602710171936302.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597951174666655.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9598540224256575.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593757099809062.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.958719517155425.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591073921649764.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594359458241963.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594660637458414.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9586789156451372.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9595602457305275.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594796533627807.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593119651784598.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597647123238127.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592717222046856.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593266762515857.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594086284310437.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591012981455986.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594455088342952.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592775023805833.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593758469184286.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594167534598128.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593381622487982.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959501289796329.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959443897898418.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9595053401852964.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593799567329229.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(1.95937996).
#   warnings.warn(
# Mejor ajuste: lognorm
# Parámetros estimados: (0.6102686937681471, 3.3772486057305384, 0.8398421049452021)
# Prueba KS p-value: 0.3851

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kstest, norm, expon, lognorm, weibull_min, gamma, erlang, triang, logistic, halfnorm, cauchy
from matplotlib import style

# Aplicar estilo ggplot
style.use('ggplot')

# Cargar el archivo CSV con el delimitador y el separador decimal adecuados
file_path = 'tiempos_iteraciones.csv'
df = pd.read_csv(file_path)

# Extraer la columna de interés
tiempos_iteracion = df['TiempoIteracion']

# Distribuciones para probar
distribuciones = {
    'norm': norm,
    'expon': expon,
    'lognorm': lognorm,
    'weibull_min': weibull_min,
    'gamma': gamma,
    'erlang': erlang,
    'triang': triang,
    'logistic': logistic,
    'halfnorm': halfnorm,
    'cauchy': cauchy
}

# Inicializar variables para el mejor ajuste
best_fit_name = None
best_fit_params = None
best_kstest_result = None
best_fit_curve = None

# Iterar sobre las distribuciones y encontrar el mejor ajuste
for distribution_name, distribution in distribuciones.items():
    # Ajustar los datos a la distribución actual
    params = distribution.fit(tiempos_iteracion)
    
    # Realizar la prueba de ajuste de Kolmogorov-Smirnov
    kstest_result = kstest(tiempos_iteracion, distribution.cdf, params)
    
    # Actualizar el mejor ajuste si es necesario
    if best_fit_name is None or kstest_result.pvalue > best_kstest_result.pvalue:
        best_fit_name = distribution_name
        best_fit_params = params
        best_kstest_result = kstest_result
        best_fit_curve = distribution.pdf(np.linspace(min(tiempos_iteracion), max(tiempos_iteracion), 100), *params)

# Imprimir los resultados
print(f'Mejor ajuste: {best_fit_name}')
print(f'Parámetros estimados: {best_fit_params}')
print(f'Prueba KS p-value: {best_kstest_result.pvalue:.4f}')

# Crear un DataFrame con los resultados del mejor ajuste
results_df = pd.DataFrame({
    'Distribution': [best_fit_name],
    'Parameters': [best_fit_params],
    'KS_pvalue': [best_kstest_result.pvalue]
})

# Guardar los resultados del mejor ajuste en un archivo CSV
results_df.to_csv('resultados_distribucion_mejor_ajuste.csv', index=False)

# Visualizar histograma de los tiempos de iteración y gráficos para la mejor distribución
plt.hist(tiempos_iteracion, bins=20, density=True, alpha=0.5, color='g')
plt.plot(np.linspace(min(tiempos_iteracion), max(tiempos_iteracion), 100), best_fit_curve, label=f'{best_fit_name} - p-value: {best_kstest_result.pvalue:.4f}')

# Configuración del gráfico
plt.title(f'Tiempo de iteraciones en segundos\nMejor ajuste: {best_fit_name}\nPrueba KS p-value: {best_kstest_result.pvalue:.4f}')
plt.xlabel('Tiempo de Iteración (s)')
plt.ylabel('Frecuencia')
plt.legend()

# Guardar la imagen en un archivo PNG
plt.savefig('histograma_tiempos_mejor_ajuste.png')

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.2.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.133333333333333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.033333333333333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.155555555555557.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.233333333333334.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.9777777777777787.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.866666666666669.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.08888888888889.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.022222222222222.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.048148148148151.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.076543209876547.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.062962962962966.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.751851851851856.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.7395061728395094.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.027572016460907.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.820781893004119.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.5550068587105645.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3010288065843643.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.5861454046639256.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.3484453589391867.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 3.112277091906721.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.7996342021033387.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.266117969821673.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.5558146623990234.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.344121831021691.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8656683432403547.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.020770038442648.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.8394003285407026.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.766289578711465.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.433963412683627.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2299490128411836.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9057332589862028.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2259299889531636.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2289442568691786.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.7656197413967947.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1207048795888506.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.028550565636186.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8258441421124658.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0999739272953066.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8220310839918712.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.213599144264236.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.107377545208302.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.100713878018028.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.133044242777176.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.1082415061657738.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.2575948981226883.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0858116487578116.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.987354655823689.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0121210603607613.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9640608374582555.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9533837102356868.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.0527046641272806.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.095407375372203.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9674043727635233.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.965210392935374.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.049048031080365.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8901387989437932.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.8305586551445834.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9944256870964194.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9338731560636049.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9573760837174317.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 2.053769606570945.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9310465008505813.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9578380103180328.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9625051306732.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9061927897310555.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9723674627550785.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.997119283913226.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9475646966162423.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9642487763122491.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959094256866136.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9568458134851046.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9582606427821283.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9789168783193194.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9554027420420117.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9428042983717724.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9649766716592518.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9599991141227922.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597728998086281.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9618408995577996.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591557069760461.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9599171806429116.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9598811104343408.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9672729173377475.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9583702858659455.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9532947305249704.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9620561863756816.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.961049348141266.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959629117267351.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9601559492383112.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9600872395373186.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.956668242071395.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9607092002996098.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9619134188702412.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592560691170195.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9604058887019478.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9602116958432987.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9600307373026333.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9589564678756908.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9602710171936302.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597951174666655.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9598540224256575.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593757099809062.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.958719517155425.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591073921649764.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594359458241963.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594660637458414.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9586789156451372.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9595602457305275.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594796533627807.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593119651784598.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9597647123238127.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592717222046856.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593266762515857.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594086284310437.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9591012981455986.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594455088342952.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9592775023805833.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593758469184286.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9594167534598128.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593381622487982.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959501289796329.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.959443897898418.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9595053401852964.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 1.9593799567329229.
#   warnings.warn(
# C:\Users\UNIMAG\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\stats\_continuous_distns.py:3417: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(1.95937996).
#   warnings.warn(
# Mejor ajuste: lognorm
# Parámetros estimados: (0.6102686937681471, 3.3772486057305384, 0.8398421049452021)
# Prueba KS p-value: 0.3851
