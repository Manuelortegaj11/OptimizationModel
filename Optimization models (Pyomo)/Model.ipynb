# %% [markdown]
# # 1. Importa la librería Pyomo

# %%
from pyomo.environ import*
import pandas as pd

# %% [markdown]
# # 2. Crea un modelo de Pyomo

# %%
# Crear un modelo con Pyomo
model = ConcreteModel()

# %% [markdown]
# # 3. Conjuntos

# %%
model.I = Set()  # Conjunto de productores
model.J = Set()  # Conjunto de centros de acopio
model.K = Set()  # Conjunto de clientes
model.P = Set()  # Conjunto de productos
model.T = Set()  # Conjunto de periodos de tiempo

# %% [markdown]
# # 4. Inicializar conjuntos con valores únicos del archivo

# %% [markdown]
# Cargamos la base de datos del costo de producción

# %%
# Cargar CostoProduccion desde un archivo CSV
CostoProduccion = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoProduccion.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.I)
model.del_component(model.T)

model.P = Set(initialize=CostoProduccion['P'].unique())
model.I = Set(initialize=CostoProduccion['I'].unique())
model.T = Set(initialize=CostoProduccion['T'].unique())

# %% [markdown]
# Cargamos la base de datos de los costos de operación

# %%
# Cargar CostoFijoAcopio desde un archiCostoFijoAcopiovo CSV
CostoFijoAcopio = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoFijoAcopio.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.J)
model.del_component(model.T)

model.J = Set(initialize=CostoFijoAcopio['J'].unique())
model.T = Set(initialize=CostoFijoAcopio['T'].unique())

# %%
# Cargar CostoVarAcopio desde un archivo CSV
CostoVarAcopio = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoVarAcopio.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.J)
model.del_component(model.T)

model.P = Set(initialize=CostoVarAcopio['P'].unique())
model.J = Set(initialize=CostoVarAcopio['J'].unique())
model.T = Set(initialize=CostoVarAcopio['T'].unique())

# %% [markdown]
# Cargamos la base de datos de los costos de inventario

# %%
# Cargar CostoInvAcopio desde un archivo CSV
CostoInvAcopio = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoInvAcopio.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.J)
model.del_component(model.T)

model.P = Set(initialize=CostoInvAcopio['P'].unique())
model.J = Set(initialize=CostoInvAcopio['J'].unique())
model.T = Set(initialize=CostoInvAcopio['T'].unique())

# %% [markdown]
# Cargamos la base de datos de los costos de transporte

# %%
# Cargar CostoTransProdAcopio desde un archivo CSV
CostoTransProdAcopio = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoTransProdAcopio.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.I)
model.del_component(model.J)
model.del_component(model.T)

model.P = Set(initialize=CostoTransProdAcopio['P'].unique())
model.I = Set(initialize=CostoTransProdAcopio['I'].unique())
model.J = Set(initialize=CostoTransProdAcopio['J'].unique())
model.T = Set(initialize=CostoTransProdAcopio['T'].unique())

# %%
# Cargar CostoTransAcopioClie desde un archivo CSV
CostoTransAcopioClie = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CostoTransAcopioClie.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.J)
model.del_component(model.K)
model.del_component(model.T)

model.P = Set(initialize=CostoTransAcopioClie['P'].unique())
model.J = Set(initialize=CostoTransAcopioClie['J'].unique())
model.K = Set(initialize=CostoTransAcopioClie['K'].unique())
model.T = Set(initialize=CostoTransAcopioClie['T'].unique())

# %% [markdown]
# Cargamos la base de datos de la demanda

# %%
# Cargar DemandaClie desde un archivo CSV
DemandaClie = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\DemandaClie.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.K)
model.del_component(model.T)

model.P = Set(initialize=DemandaClie['P'].unique())
model.K = Set(initialize=DemandaClie['K'].unique())
model.T = Set(initialize=DemandaClie['T'].unique())

# %% [markdown]
# Cargamos la base de datos de las capacidades

# %%
# Cargar CapProductor desde un archivo CSV
CapProductor = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CapProductor.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.I)
model.del_component(model.T)

model.P = Set(initialize=CapProductor['P'].unique())
model.I = Set(initialize=CapProductor['I'].unique())
model.T = Set(initialize=CapProductor['T'].unique())

# %%
# Cargar CapAlmacenamientoCA desde un archivo CSV
CapAlmacenamientoCA = pd.read_csv(r'C:\Users\UNIMAG\Desktop\PROYECTO DE QUESO COSTEÑO\FASE III\Noviembre\MODELO DE OPTIMIZACION - Pyomo\CORDOBA\CapAlmacenamientoCA.csv', delimiter=';', decimal=',')

# Inicializar conjuntos con valores únicos del archivo
model.del_component(model.P)
model.del_component(model.J)
model.del_component(model.T)

model.P = Set(initialize=CapAlmacenamientoCA['P'].unique())
model.J = Set(initialize=CapAlmacenamientoCA['J'].unique())
model.T = Set(initialize=CapAlmacenamientoCA['T'].unique())

# %% [markdown]
# # 5.  Parámetros

# %%
model.CostoProduccion = Param(model.P, model.I, model.T, within=NonNegativeReals, initialize=CostoProduccion.set_index(['P', 'I', 'T'])['CostoProduccion'].to_dict())  # Costos de producción
model.CostoFijoAcopio = Param(model.J, model.T, within=NonNegativeReals, initialize=CostoFijoAcopio.set_index(['J', 'T'])['CostoFijoAcopio'].to_dict())  # Costos fijos de acopio
model.CostoVariableAcopio = Param(model.P, model.J, model.T, within=NonNegativeReals, initialize=CostoVarAcopio.set_index(['P', 'J', 'T'])['CostoVarAcopio'].to_dict())  # Costos variables de acopio
model.CostoInventario = Param(model.P, model.J, model.T, within=NonNegativeReals, initialize=CostoInvAcopio.set_index(['P', 'J', 'T'])['CostoInvAcopio'].to_dict())  # Costos de inventario
model.CostoTransporteProducto = Param(model.P, model.I, model.J, model.T, within=NonNegativeReals, initialize=CostoTransProdAcopio.set_index(['P', 'I', 'J', 'T'])['CostoTransProdAcopio'].to_dict())  # Costos de transporte de producto
model.CostoTransAcopioCliente = Param(model.P, model.J, model.K, model.T, within=NonNegativeReals, initialize=CostoTransAcopioClie.set_index(['P', 'J', 'K', 'T'])['CostoTransAcopioClie'].to_dict())  # Costos de transporte de acopio a cliente
model.DemandaCliente = Param(model.P, model.K, model.T, within=NonNegativeReals, initialize=DemandaClie.set_index(['P', 'K', 'T'])['DemandaClie'].to_dict())  # Demanda de clientes
model.CapacidadProductor = Param(model.P, model.I, model.T, within=NonNegativeReals, initialize=CapProductor.set_index(['P', 'I', 'T'])['CapProductor'].to_dict())  # Capacidad de productores
model.CapacidadAlmacenamientoAcopio = Param(model.P, model.J, model.T, within=NonNegativeReals, initialize=CapAlmacenamientoCA.set_index(['P', 'J', 'T'])['CapAlmacenamientoCA'].to_dict())  # Capacidad de almacenamiento de acopio

# %% [markdown]
# # 6. Variables de decisión

# %%
model.BinariaOperacion = Var(model.J, model.T, within=Binary)  # Variable binaria para activación para la operacion del centro de acopio en cada periodo
model.BinariaAsignacion = Var(model.I, model.J, model.T, within=Binary)  # Variable binaria para la asignacion del productor al centro de acopio en cada periodo
model.CantidadProductoEnviada = Var(model.P, model.I, model.J, model.T, within=NonNegativeReals)  # Cantidad de producto enviada del productor al centro de acopio en cada periodo
model.CantidadProductoEnviadaCliente = Var(model.P, model.J, model.K, model.T, within=NonNegativeReals)  # Cantidad de producto enviada del centro de acopio al cliente en cada periodo
model.CantidadProductoAlmacenadaAcopio = Var(model.P, model.J, model.T, within=NonNegativeReals)  # Cantidad de producto almacenada en el centro de acopio en cada periodo
model.DemandaInsatisfecha = Var(model.P, model.T, within=NonNegativeReals)  # Demanda insatisfecha en cada periodo

# %% [markdown]
# # 7 . Función objetivo

# %%
def objective_rule(model):
    return sum(model.CostoProduccion[p, i, t] * model.CantidadProductoEnviada [p, i, j, t] for p in model.P for i in model.I for j in model.J for t in model.T) + \
           sum(model.CostoFijoAcopio[j, t] * model.BinariaOperacion[j, t] for j in model.J for t in model.T) + \
           sum(model.CostoVariableAcopio[p, j, t] * model.CantidadProductoEnviada[p, i, j, t] for p in model.P for i in model.I for j in model.J for t in model.T) + \
           sum(model.CostoInventario[p, j, t] * model.CantidadProductoAlmacenadaAcopio[p, j, t] for p in model.P for j in model.J for t in model.T) + \
           sum(model.CostoTransporteProducto[p, i, j, t] * model.CantidadProductoEnviada[p, i, j, t] for p in model.P for i in model.I for j in model.J for t in model.T) + \
           sum(model.CostoTransAcopioCliente[p, j, k, t] * model.CantidadProductoEnviadaCliente[p, j, k, t] for p in model.P for j in model.J for k in model.K for t in model.T) + \
           sum(model.DemandaInsatisfecha[p, t] for p in model.P for t in model.T) * 0 # falta agregar la penalizacion de la demanda insatisfecha
model.obj = Objective(rule=objective_rule, sense=minimize)

# %% [markdown]
# # 8. Restricciones de capacidad y demanda

# %%
# Restricciones - Capacidad de productores
def capacity_producer_rule(model, p, i, j, t):
    return model.CantidadProductoEnviada[p, i, j, t] <= model.CapacidadProductor[p, i, t] * model.BinariaAsignacion[i, j, t]
CapacityProducerRule = Constraint(model.P, model.I, model.J, model.T, rule=capacity_producer_rule)

# Restricciones - Flujo
def flow_rule(model, p, j, t):
    if t == 1:
        return sum(model.CantidadProductoEnviada[p, i, j, t] for i in model.I) == model.CantidadProductoAlmacenadaAcopio[p, j, t] + sum(model.CantidadProductoEnviadaCliente[p, j, k, t] for k in model.K)
    else:
        return sum(model.CantidadProductoEnviada[p, i, j, t] for i in model.I) + model.CantidadProductoAlmacenadaAcopio[j, p, t - 1] == model.CantidadProductoAlmacenadaAcopio[p, j, t] + sum(model.CantidadProductoEnviadaCliente[p, j, k, t] for k in model.K)
Flow = Constraint(model.P, model.J, model.T, rule=flow_rule)

# Restricciones - Relación de variables binarias y de operación
def binary_operation_rule(model, p, j, t):
    return sum(model.CantidadProductoEnviada[p, i, j, t] for i in model.I) <= model.BinariaOperacion[j, t] * model.CapacidadAlmacenamientoAcopio[p, j, t]
BinaryOperation = Constraint(model.P, model.J, model.T, rule=binary_operation_rule)

# Restricciones - Asignación de envíos desde productores a centros de acopio
def assignment_producer_rule(model, i, t):
    return sum(model.BinariaAsignacion[i, j, t] for j in model.J) == 1
AssignmentProducer = Constraint(model.I, model.T, rule=assignment_producer_rule)

# Restricciones - Demanda insatisfecha
def demand_unsatisfied_rule(model, p, t):
    return sum(model.CantidadProductoAlmacenadaAcopio[p, j, k, t] for j in model.J for k in model.K) + model.DemandaInsatisfecha[p, t] == sum(model.DemandaCliente[p, k, t] for k in model.K)
DemandaInsatisfecha = Constraint(model.P, model.T, rule=demand_unsatisfied_rule)

# %% [markdown]
# # 9. Resuelve el modelo

# %%
# Resuelve el modelo
solver = SolverFactory('glpk')
results = solver.solve(model)

# %% [markdown]
# # 10. Imprime los resultados

# %%
if results.solver.termination_condition == TerminationCondition.optimal:
    print("El modelo se resolvió de manera óptima.")
    for p in model.P:
        for i in model.I:
            for j in model.J:
                for t in model.T:
                    print(f"Cantidad Producto del Productor Enviada al Centro de Acopio en periodo de tiempo